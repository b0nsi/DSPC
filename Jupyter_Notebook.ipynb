# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Sasha Bonsignore</b><br>Currently working as Head of Architecture in the financial industry

# %% [markdown]
# <i>I am insterested in Data Science to strenghten my skills</i>

# %% [markdown]
# <h3>Code snippet to print 'Hello, world!!!'</h3>

# %%
print('Hello, world!!!')

# %% [markdown]
# <hr>
# Objectives of the exercise
# <hr>
#
# <ul>
# <li>Create a Jupyter Notebook</li>
# <li>Create markdown cells</li>
# <li>Create some code cells</li>
# </ul>
#
# Contents are as follows:
# <ol>
# <li>Title cell</li>
# <li>Author and occupation cell</li>
# <li>'Why learning data science?' cell</li>
# <li>Code explanation cell</li>
# <li>Code snitppet cell</li>
# <li>Description of the exercise in HTML/Markdown cell</li>
# </ol>
#
# <p> We can add a table should we wish to
# <table style="width:20%">
# <tr><th>COL 1</th><th>COL 2</th></tr>
# <tr><th>VAL 1</th><th>VAL 2</th></tr>
# </table>
# </p>
#
#  <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
